# %% [markdown]
# <a href="https://colab.research.google.com/github/25041106-rgb/POO/blob/main/UNIDAD%201/POO2(mav).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def mifuncion():

  variableX = 123

result_mifuncion = mifuncion()
print(result_mifuncion)


def sifuncion():
  global variable
  variable = 2
  print("¿valor de la variable?:", variable)

variable = 1
print("valor de la variable", variable)
sifuncion()
print("valor de la variable:", variable)
# Out:
# None
# valor de la variable 1
# ¿valor de la variable?: 2
# valor de la variable: 2
