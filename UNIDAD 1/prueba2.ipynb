# %% [markdown]
# <a href="https://colab.research.google.com/github/25041106-rgb/POO/blob/main/UNIDAD%201/prueba2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
    print("""selecciona una opcion
1) opcion 1
2) opcion 2
3) salir""")
    opcion= input ("¿cual es la opcion que deseas?")
    if opcion == "1":
        print("seleccionaste la opcion 1")
    elif opcion == "2":
        print("seleccionaste la opcion 2")
    elif opcion == "3":
        print("seleccionaste la opcion salir")
        break
    else:
        print("seleccion erronea")
# Out:
# selecciona una opcion
# 1) opcion 1
# 2) opcion 2
# 3) salir
# ¿cual es la opcion que deseas?1
# seleccionaste la opcion 1
# selecciona una opcion
# 1) opcion 1
# 2) opcion 2
# 3) salir
# ¿cual es la opcion que deseas?2
# seleccionaste la opcion 2
# selecciona una opcion
# 1) opcion 1
# 2) opcion 2
# 3) salir
# ¿cual es la opcion que deseas?3
# seleccionaste la opcion salir
