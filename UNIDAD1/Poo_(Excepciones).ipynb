# %% [markdown]
# <a href="https://colab.research.google.com/github/25041106-rgb/POO/blob/main/UNIDAD1/Poo_(Excepciones).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while (True):
  try:
    x = float(input("introduce un numero:  "))
    y = 5
    print("la multiplicacion de", y, "por", x, "es =", x*y, )

  except:
    print("Ha ocurrido un error :D")
  else:
    print("TODO FUNCIONO BIEN")
    break
  finally:
    print("codigo final")
# Out:
# introduce un numero:  10
# la multiplicacion de 5 por 10.0 es= 50.0
# TODO FUNCIONO BIEN
# codigo final
