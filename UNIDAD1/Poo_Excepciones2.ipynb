# %% [markdown]
# <a href="https://colab.research.google.com/github/25041106-rgb/POO/blob/main/UNIDAD1/Poo_Excepciones2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while (True):
  try:
    x = float(input("introduce un numero:  "))
    y = 100
    print("la Division de", y, "entre", x, "es =", x/y, )

  except ValueError:
    print("No es numerico el valor proporcionado")
  except ZeroDivisionError:
    print("No puedes dividir entre cero")
  except Exception as e:
    print("error", type(e).__name__)
  else:
    print("TODO FUNCIONO BIEN")
    break
  finally:
    print("codigo final")
# Out:
# introduce un numero:  50
# la Division de 100 entre 50.0 es = 0.5
# TODO FUNCIONO BIEN
# codigo final
